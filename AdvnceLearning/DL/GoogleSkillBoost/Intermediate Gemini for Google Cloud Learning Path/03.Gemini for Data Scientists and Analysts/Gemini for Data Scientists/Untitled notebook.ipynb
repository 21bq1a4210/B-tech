# %%
from google.cloud import bigquery
from google.cloud import aiplatform
import bigframes.pandas as bpd
import pandas as pd
from vertexai.language_models._language_models import TextGenerationModel
from bigframes.ml.cluster import KMeans
from bigframes.ml.model_selection import train_test_split

# %%
project_id = 'qwiklabs-gcp-03-4138d4db502c'
dataset_name = "ecommerce"
model_name = "customer_segmentation_model"
table_name = "customer_stats"
location = "us-central1"
client = bigquery.Client(project=project_id)
aiplatform.init(project=project_id, location=location)

# %%
# %%bigquery
# CREATE OR REPLACE TABLE ecommerce.customer_stats AS
# SELECT
#   user_id,
#   DATE_DIFF(CURRENT_DATE(), CAST(MAX(order_created_date) AS DATE), day) AS days_since_last_order, ---RECENCY
#   COUNT(order_id) AS count_orders, --FREQUENCY
#   AVG(sale_price) AS average_spend --MONETARY
#   FROM (
#       SELECT
#         user_id,
#         order_id,
#         sale_price,
#         created_at AS order_created_date
#         FROM `bigquery-public-data.thelook_ecommerce.order_items`
#         WHERE
#         created_at
#             BETWEEN '2022-01-01' AND '2023-01-01'
#   )
# GROUP BY user_id;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# prompt: Convert the table ecommerce.customer_stats to a BigQuery DataFrames dataframe and show the top 10 records

bqdf = client.query(f"SELECT * FROM `{project_id}.{dataset_name}.{table_name}`").to_dataframe()
bqdf.head(10)
# Out:
#    user_id  days_since_last_order  count_orders  average_spend
# 0    90202                    768             1     128.000000
# 1    67148                    768             1      16.790001
# 2    78660                    768             1     199.990005
# 3    89949                    768             1     119.000000
# 4    67859                    768             1      24.000000
# 5    76745                    768             1      49.500000
# 6     5563                    768             1      11.350000
# 7    49304                    768             1      39.990002
# 8    27585                    768             1      36.000000
# 9    22481                    768             1      18.000000

# %%
df = bpd.read_gbq(f"{project_id}.{dataset_name}.{table_name}")
df.head(10)
# Out:
# Query job 36219a0d-4057-4658-a651-e51435c82df1 is DONE. 634.9 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:36219a0d-4057-4658-a651-e51435c82df1&page=queryresults">Open Job</a>
# Query job 76815e3c-a18c-4133-a0e8-ee13ea2917e4 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:76815e3c-a18c-4133-a0e8-ee13ea2917e4&page=queryresults">Open Job</a>
# Query job 9325e7db-099a-420b-9835-fb4f28d7ada0 is DONE. 480 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:9325e7db-099a-420b-9835-fb4f28d7ada0&page=queryresults">Open Job</a>
#    user_id  days_since_last_order  count_orders  average_spend
# 0    68248                    914             1           43.5
# 1      191                    662             2      53.665001
# 2    12545                    888             1           49.5
# 3    78334                    724             1           69.5
# 4    56879                    681             1          11.44
# 5    50069                    665             5         60.648
# 6    35867                    738             2         16.995
# 7    97526                    819             1      39.950001
# 8    24232                    710             3      17.216667
# 9     3527                    793             3      28.613334
#
# [10 rows x 4 columns]

# %%
#prompt: 1. Split df into test and training data for a K-means clustering algorithm store these as df_test_ and df_train. 2. Create a K-means cluster model using bigframes.ml.cluster KMeans with 5 clusters. 3. Save the model to BigQuery in a model called ecommerce.model_name using the to_gbq method.

df_train, df_test = train_test_split(df, test_size=0.2,  random_state=42)
model = KMeans(n_clusters=5)
model.fit(df_train)
model.to_gbq(f"{project_id}.{dataset_name}.{model_name}")
# Out:
# Query job 5b48e7e7-9779-4a85-8516-b628a698e530 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:5b48e7e7-9779-4a85-8516-b628a698e530&page=queryresults">Open Job</a>
# Query job ecb18a65-1680-4260-b5c9-75b16328c0fd is DONE. 634.9 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:ecb18a65-1680-4260-b5c9-75b16328c0fd&page=queryresults">Open Job</a>
# Query job 28373ae3-a62e-4d1d-8daf-abdc19e4ff62 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:28373ae3-a62e-4d1d-8daf-abdc19e4ff62&page=queryresults">Open Job</a>
# Copy job 58e65daa-b937-40f9-af98-6dc03092dfec is DONE. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:58e65daa-b937-40f9-af98-6dc03092dfec&page=queryresults">Open Job</a>
# KMeans(distance_type='EUCLIDEAN', init='KMEANS_PLUS_PLUS', n_clusters=5)

# %%
# prompt: 1. Call the K-means prediction model on the df dataframe, and store the results as predictions_df and show the first 10 records.

predictions_df = model.predict(df)
predictions_df.head(10)
# Out:
# Query job 926458e8-dd22-4a75-aca9-412c6ac7b77e is DONE. 635.1 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:926458e8-dd22-4a75-aca9-412c6ac7b77e&page=queryresults">Open Job</a>
# Query job 6d36ab05-860b-4caa-a61e-51409c1c41aa is DONE. 2.5 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:6d36ab05-860b-4caa-a61e-51409c1c41aa&page=queryresults">Open Job</a>
# Query job 908b476e-7af3-468b-b6b7-80d791839ed4 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:908b476e-7af3-468b-b6b7-80d791839ed4&page=queryresults">Open Job</a>
# Query job 7a360711-7ed0-4012-964c-3c3b22478a01 is DONE. 1.4 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-4138d4db502c&j=bq:US:7a360711-7ed0-4012-964c-3c3b22478a01&page=queryresults">Open Job</a>
#    CENTROID_ID                         NEAREST_CENTROIDS_DISTANCE  user_id  \
# 0            1  [{'CENTROID_ID': 1, 'DISTANCE': 1.157802235076...    68248
# 1            3  [{'CENTROID_ID': 3, 'DISTANCE': 0.913769464247...      191
# 2            4  [{'CENTROID_ID': 4, 'DISTANCE': 1.833178317412...    12545
# 3            1  [{'CENTROID_ID': 1, 'DISTANCE': 0.968544516038...    78334
# 4            1  [{'CENTROID_ID': 1, 'DISTANCE': 1.367844582889...    56879
# 5            5  [{'CENTROID_ID': 5, 'DISTANCE': 2.723897017012...    50069
# 6            3  [{'CENTROID_ID': 3, 'DISTANCE': 1.082671259621...    35867
# 7            1  [{'CENTROID_ID': 1, 'DISTANCE': 1.077488634415...    97526
# 8            3  [{'CENTROID_ID': 3, 'DISTANCE': 1.609159963203...    24232
# 9            3  [{'CENTROID_ID': 3, 'DISTANCE': 2.027231394063...     3527
#
#    days_since_last_order  count_orders  average_spend
# 0                    914             1           43.5
# 1                    662             2      53.665001
# 2                    888             1           49.5
# 3                    724             1           69.5
# 4                    681             1          11.44
# 5                    665             5         60.648
# 6                    738             2         16.995
# 7                    819             1      39.950001
# 8                    710             3      17.216667
# 9                    793             3      28.613334
#
# [10 rows x 6 columns]

# %%
#prompt: 1. Using predictions_df, and matplotlib, generate a scatterplot. 2. On the x-axis of the scatterplot, display days_since_last_order and on the y-axis, display average_spend from predictions_df. 3. Color by cluster. The chart should be titled "Attribute grouped by K-means cluster."


import matplotlib.pyplot as plt

plt.scatter(predictions_df['days_since_last_order'], predictions_df['average_spend'], c=predictions_df['cluster'])
plt.xlabel("days_since_last_order")
plt.ylabel("average_spend")
plt.title("Attribute grouped by K-means Cluster")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-6370fdb1e36f> in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 plt.scatter(predictions_df['days_since_last_order'], predictions_df['average_spend'], c=predictions_df['cluster'])
#       7 plt.xlabel("days_since_last_order")
#       8 plt.ylabel("average_spend")
#
# /usr/local/lib/python3.10/dist-packages/bigframes/core/log_adapter.py in wrapper(*args, **kwargs)
#      54
#      55         try:
# ---> 56             return method(*args, **kwargs)
#      57         finally:
#      58             _call_stack.pop()
#
# /usr/local/lib/python3.10/dist-packages/bigframes/dataframe.py in __getitem__(self, key)
#     511
#     512         if isinstance(key, typing.Hashable):
# --> 513             return self._getitem_label(key)
#     514         # Select a subset of columns or re-order columns.
#     515         # In Ibis after you apply a projection, any column objects from the
#
# /usr/local/lib/python3.10/dist-packages/bigframes/core/log_adapter.py in wrapper(*args, **kwargs)
#      54
#      55         try:
# ---> 56             return method(*args, **kwargs)
#      57         finally:
#      58             _call_stack.pop()
#
# /usr/local/lib/python3.10/dist-packages/bigframes/dataframe.py in _getitem_label(self, key)
#     540         col_ids = self._block.cols_matching_label(key)
#     541         if len(col_ids) == 0:
# --> 542             raise KeyError(key)
#     543         block = self._block.select_columns(col_ids)
#     544         if isinstance(self.columns, pandas.MultiIndex):
#
# KeyError: 'cluster'

# %%
query = """
SELECT
 CONCAT('cluster ', CAST(centroid_id as STRING)) as centroid,
 average_spend,
 count_orders,
 days_since_last_order
FROM (
 SELECT centroid_id, feature, ROUND(numerical_value, 2) as value
 FROM ML.CENTROIDS(MODEL `{0}.{1}`)
)
PIVOT (
 SUM(value)
 FOR feature IN ('average_spend',  'count_orders', 'days_since_last_order')
)
ORDER BY centroid_id
""".format(dataset_name, model_name)

df_centroid = client.query(query).to_dataframe()
df_centroid.head()
# Out:
#     centroid  average_spend  count_orders  days_since_last_order
# 0  cluster 1          43.94          1.36                 799.47
# 1  cluster 2         665.02          1.13                 734.34
# 2  cluster 3          45.19          1.47                 668.55
# 3  cluster 4         136.75          1.41                 797.89
# 4  cluster 5          56.27          2.30                 625.61

# %%
df_query = client.query(query).to_dataframe()
df_query.to_string(header=False, index=False)

cluster_info = []
for i, row in df_query.iterrows():
 cluster_info.append("{0}, average spend ${2}, count of orders per person {1}, days since last order {3}"
  .format(row["centroid"], row["count_orders"], row["average_spend"], row["days_since_last_order"]) )

cluster_info = (str.join("\n", cluster_info))
print(cluster_info)
# Out:
# cluster 1, average spend $43.94, count of orders per person 1.36, days since last order 799.47
# cluster 2, average spend $665.02, count of orders per person 1.13, days since last order 734.34
# cluster 3, average spend $45.19, count of orders per person 1.47, days since last order 668.55
# cluster 4, average spend $136.75, count of orders per person 1.41, days since last order 797.89
# cluster 5, average spend $56.27, count of orders per person 2.3, days since last order 625.61

# %%
prompt = f"""
You're a creative brand strategist, given the following clusters, come up with \
creative brand persona, a catchy title, and next marketing action, \
explained step by step.

Clusters:
{cluster_info}

For each Cluster:
* Title:
* Persona:
* Next marketing step:
"""

# %%
#prompt:  Use the Vertex AI language_models API to call the PaLM2 text-bison model and generate a marketing campaign using the variable prompt. Use the following model settings: max_output_tokens=1024, temperature=0.4

model = TextGenerationModel.from_pretrained("text-bison")
response = model.predict(prompt, max_output_tokens=1024, temperature=0.4)
print(response.text)
# Out:
#  **Cluster 1**
#
# **Title:** The Occasional Shoppers
#
# **Persona:** These customers make infrequent purchases, with an average of 1.36 orders per person and a long time between orders (799.47 days). They tend to spend a moderate amount per order ($43.94), indicating that they may be looking for specific items or making occasional purchases.
#
# **Next marketing step:**
# - **Targeted email campaigns:** Send personalized emails to these customers highlighting new products or special offers that align with their previous purchases.
# - **Remarketing ads:** Use remarketing ads to remind these customers about products they've viewed or added to their carts but didn't purchase.
# - **Loyalty program:** Implement a loyalty program to reward these customers for their occasional purchases and encourage them to make more frequent visits.
#
# **Cluster 2**
#
# **Title:** The Big Spenders
#
# **Persona:** These customers are characterized by their high average spend ($665.02) and relatively low order frequency (1.13 orders per person). They tend to make significant purchases when they do order, indicating that they may be looking for luxury items or special occasion purchases.
#
# **Next marketing step:**
# - **Exclusive offers:** Provide exclusive offers and discounts to these customers to make them feel valued and appreciated.
# - **Personalized recommendations:** Use data on their previous purchases to provide personalized product recommendations that cater to their preferences and interests.
# - **VIP program:** Create a VIP program that offers special perks and benefits to these high-value customers.
#
# **Cluster 3**
#
# **Title:** The Steady Buyers
#
# **Persona:** These customers make regular purchases, with an average of 1.47 orders per person and a relatively short time between orders (668.55 days). They tend to spend a moderate amount per order ($45.19), indicating that they may be purchasing everyday essentials or frequently used items.
#
# **Next marketing step:**
# - **Subscription services:** Offer subscription services or recurring orders for products that these customers regularly purchase.
# - **Bundle offers:** Create bundle offers or discounts for complementary products that these customers might be interested in.
# - **Customer loyalty program:** Implement a customer loyalty program to reward these steady buyers for their consistent purchases.
#
# **Cluster 4**
#
# **Title:** The Occasional Indulgers
#
# **Persona:** These customers make infrequent purchases, similar to Cluster 1, but with a higher average spend ($136.75) per order. They tend to make occasional splurge purchases, possibly for special occasions or luxury items.
#
# **Next marketing step:**
# - **Event-based marketing:** Target these customers with marketing campaigns tied to specific events or holidays when they might be more likely to make indulgent purchases.
# - **Limited-time offers:** Create limited-time offers or flash sales to encourage these customers to make impulse purchases.
# - **Social media engagement:** Engage with these customers on social media platforms to build a connection and showcase products that align with their interests.
#
# **Cluster 5**
#
# **Title:** The Frequent Value Seekers
#
# **Persona:** These customers make the most frequent purchases, with an average of 2.3 orders per person and a relatively short time between orders (625.61 days). They tend to spend a moderate amount per order ($56.27), indicating that they may be looking for value-driven purchases or everyday essentials.
#
# **Next marketing step:**
# - **Flash sales and discounts:** Offer regular flash sales or discounts to appeal to these value-conscious customers.
# - **Free shipping promotions:** Provide free shipping promotions to encourage these customers to make more frequent purchases.
# - **Upselling and cross-selling:** Use upselling and cross-selling techniques to recommend complementary products or upgrades that enhance their shopping experience.

# %%
# Delete customer_stats table

client.delete_table(f"{project_id}.{dataset_name}.{table_name}", not_found_ok=True)
print(f"Deleted table: {project_id}.{dataset_name}.{table_name}")


# Delete K-means model
client.delete_model(f"{project_id}.{dataset_name}.{model_name}", not_found_ok=True)
print(f"Deleted model: {project_id}.{dataset_name}.{model_name}")
# Out:
# Deleted table: qwiklabs-gcp-03-4138d4db502c.ecommerce.customer_stats
# Deleted model: qwiklabs-gcp-03-4138d4db502c.ecommerce.customer_segmentation_model
